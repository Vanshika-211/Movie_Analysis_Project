# %%
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
#reading from csv file 
ratings = pd.read_csv("./IndiaMovieDatabase/2010-2019/bollywood_ratings_2010-2019.csv")
ratings
# Out:
#         imdb_id  imdb_rating  imdb_votes
# 0     tt8291224          8.4     35112.0
# 1     tt9472208          4.1        73.0
# 2     tt6986710          6.1      5549.0
# 3     tt8108208          6.0      1891.0
# 4     tt6028796          7.3       280.0
# ..          ...          ...         ...
# 930   tt7997334          0.0         0.0
# 931   tt4718678          0.0         0.0
# 932  tt10635372          0.0         0.0
# 933   tt3482198          0.0         0.0
# 934   tt1680317          0.0         0.0
#
# [935 rows x 3 columns]

# %%
ratings.duplicated().sum()
# Out:
# 3

# %%
ratings.drop_duplicates('imdb_id' , inplace = True)

# %%
ratings.isnull().sum()
# Out:
# imdb_id         0
# imdb_rating    13
# imdb_votes     13
# dtype: int64

# %%
ratings = ratings.dropna()

# %%
ratings.isnull().sum()
ratings
# Out:
#         imdb_id  imdb_rating  imdb_votes
# 0     tt8291224          8.4     35112.0
# 1     tt9472208          4.1        73.0
# 2     tt6986710          6.1      5549.0
# 3     tt8108208          6.0      1891.0
# 4     tt6028796          7.3       280.0
# ..          ...          ...         ...
# 930   tt7997334          0.0         0.0
# 931   tt4718678          0.0         0.0
# 932  tt10635372          0.0         0.0
# 933   tt3482198          0.0         0.0
# 934   tt1680317          0.0         0.0
#
# [919 rows x 3 columns]

# %%
ratings.replace(0,np.nan ,  inplace = True)
ratings
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1852\3511337409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings.replace(0,np.nan ,  inplace = True)
#         imdb_id  imdb_rating  imdb_votes
# 0     tt8291224          8.4     35112.0
# 1     tt9472208          4.1        73.0
# 2     tt6986710          6.1      5549.0
# 3     tt8108208          6.0      1891.0
# 4     tt6028796          7.3       280.0
# ..          ...          ...         ...
# 930   tt7997334          NaN         NaN
# 931   tt4718678          NaN         NaN
# 932  tt10635372          NaN         NaN
# 933   tt3482198          NaN         NaN
# 934   tt1680317          NaN         NaN
#
# [919 rows x 3 columns]

# %%
ratings.dropna(inplace = True)
ratings
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1852\2137750393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings.dropna(inplace = True)
#         imdb_id  imdb_rating  imdb_votes
# 0     tt8291224          8.4     35112.0
# 1     tt9472208          4.1        73.0
# 2     tt6986710          6.1      5549.0
# 3     tt8108208          6.0      1891.0
# 4     tt6028796          7.3       280.0
# ..          ...          ...         ...
# 908  tt10404768          7.5        19.0
# 909  tt10360496          7.6       570.0
# 924   tt6750100          6.2        31.0
# 927   tt4303010          7.1     15895.0
# 928   tt5309720          2.7       788.0
#
# [910 rows x 3 columns]

# %%
meta = pd.read_csv("./IndiaMovieDatabase/2010-2019/bollywood_meta_2010-2019.csv")
meta
# Out:
#        imdb_id                      title             original_title  \
# 0    tt0073707                     Sholay                     Sholay
# 1    tt0246825               Om Dar-B-Dar               Om Dar-B-Dar
# 2    tt0403935             Action Jackson             Action Jackson
# 3    tt0443331            Milenge Milenge            Milenge Milenge
# 4    tt0839742  Bhopal: A Prayer for Rain  Bhopal: A Prayer for Rain
# ..         ...                        ...                        ...
# 924  tt9496212                   22 Yards                   22 Yards
# 925  tt9558612           PM Narendra Modi           PM Narendra Modi
# 926  tt9574388    Bachche Kachche Sachche    Bachche Kachche Sachche
# 927  tt9680136         Pati Patni Aur Woh         Pati Patni Aur Woh
# 928  tt9795264                  Risknamaa                  Risknamaa
#
#      is_adult year_of_release runtime                   genres
# 0           0            1975     198  Action|Adventure|Comedy
# ...

# %%
meta.isnull().sum()
# Out:
# imdb_id            0
# title              0
# original_title     0
# is_adult           0
# year_of_release    0
# runtime            0
# genres             0
# dtype: int64

# %%
meta.drop_duplicates('imdb_id', inplace = True)
meta
# Out:
#        imdb_id                      title             original_title  \
# 0    tt0073707                     Sholay                     Sholay
# 1    tt0246825               Om Dar-B-Dar               Om Dar-B-Dar
# 2    tt0403935             Action Jackson             Action Jackson
# 3    tt0443331            Milenge Milenge            Milenge Milenge
# 4    tt0839742  Bhopal: A Prayer for Rain  Bhopal: A Prayer for Rain
# ..         ...                        ...                        ...
# 924  tt9496212                   22 Yards                   22 Yards
# 925  tt9558612           PM Narendra Modi           PM Narendra Modi
# 926  tt9574388    Bachche Kachche Sachche    Bachche Kachche Sachche
# 927  tt9680136         Pati Patni Aur Woh         Pati Patni Aur Woh
# 928  tt9795264                  Risknamaa                  Risknamaa
#
#      is_adult year_of_release runtime                   genres
# 0           0            1975     198  Action|Adventure|Comedy
# ...

# %%
#merging both the ratings and met file datasets
meta_ratings = pd.merge(meta, ratings,on = "imdb_id" )
meta_ratings
# Out:
#        imdb_id                      title             original_title  \
# 0    tt0073707                     Sholay                     Sholay
# 1    tt0246825               Om Dar-B-Dar               Om Dar-B-Dar
# 2    tt0403935             Action Jackson             Action Jackson
# 3    tt0443331            Milenge Milenge            Milenge Milenge
# 4    tt0839742  Bhopal: A Prayer for Rain  Bhopal: A Prayer for Rain
# ..         ...                        ...                        ...
# 899  tt9420648                       Bala                       Bala
# 900  tt9472208              Battalion 609              Battalion 609
# 901  tt9496212                   22 Yards                   22 Yards
# 902  tt9558612           PM Narendra Modi           PM Narendra Modi
# 903  tt9795264                  Risknamaa                  Risknamaa
#
#      is_adult year_of_release runtime                   genres  imdb_rating  \
# ...

# %%
print(meta_ratings.isnull().sum(), meta_ratings.duplicated().sum(), sep = "\n\n")
# Out:
# imdb_id            0
# title              0
# original_title     0
# is_adult           0
# year_of_release    0
# runtime            0
# genres             0
# imdb_rating        0
# imdb_votes         0
# dtype: int64
#
# 0

# %%
def sortYearWise(df, colNames):
    return df.sort_values(by=colNames, ascending = False)[:1]

m= meta_ratings.groupby("year_of_release")
m = m.apply(sortYearWise ,  'imdb_votes')

# %%
fig = plt.figure()
sns.barplot(y = 'title' , x = 'imdb_votes' , data=m )
# Out:
# <Axes: xlabel='imdb_votes', ylabel='title'>
